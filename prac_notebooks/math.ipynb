# %% [markdown]
# ## Math Basics for Algorithms

# %% [markdown]
# Write a program that reads an integer from the standard input and then prints each digit of the number on a new line in reverse order.
#
# Example 1:
#
# Input:
#
# 1234
#
# Output:
#
# 4
#
# 3
#
# 2
#
# 1

# %%
n=1234
while n!=0:
    ld = n%10
    n=n//10
    print(ld)
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/abhay/Desktop/learning/dsa-python/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
